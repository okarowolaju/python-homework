# %%
# %load PyRamen.py
"""PyRamen Homework Starter."""

# @TODO: Import libraries
import csv
from pathlib import Path

# @TODO: Set file paths for menu_data.csv and sales_data.csv
menu_filepath = Path('Resources/menu_data.csv')
sales_filepath = Path('Resources/sales_data.csv')

# @TODO: Initialize list objects to hold our menu and sales data
menu = []
sales = []

# @TODO: Read in the menu data into the menu list

with open(menu_filepath, newline='') as menu_filepath:
    reader = csv.reader(menu_filepath)
    next(reader)
    for line in reader:
        menu.append(line)
        

# @TODO: Read in the sales data into the sales list

with open(sales_filepath, newline='') as sales_filepath:
    reader = csv.reader(sales_filepath)
    next(reader)
    for line in reader:
        sales.append(line)




# @TODO: Initialize dict object to hold our key-value pairs of items and metrics
report = {}

# Initialize a row counter variable
row_count = 0

# @TODO: Loop over every row in the sales list object
for i in sales:



    # Line_Item_ID,Date,Credit_Card_Number,Quantity,Menu_Item
    # @TODO: Initialize sales data variables
    Quantity = int(i[3])
    Menu_Item = i[4]
    
     

    # @TODO:
    # If the item value not in the report, add it as a new entry with initialized metrics
    # Naming convention allows the keys to be ordered in logical fashion, count, revenue, cost, profit
    
    if Menu_Item not in report:
        report[Menu_Item] = {"01-count": 0, "02-revenue": 0, "03-cogs": 0, "04-profit": 0}  
    

    for j in menu:
        if Menu_Item == j[0]:
            
            Item = j[0]
            Price = int(j[3])
            Cost = int(j[4])
            Profit = Price - Cost
            
            report[Menu_Item]["01-count"] += Quantity
            report[Menu_Item]["02-revenue"] += Price * Quantity
            report[Menu_Item]["03-cogs"] += Cost * Quantity
            report[Menu_Item]["04-profit"] += Profit * Quantity
                
           
            
with open('report.txt', 'w') as f:
    print(report, file=f)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-19-31aa2cbd2fae> in <module>
#      58
#      59 if __name__ == '__main__':
# ---> 60     main()
#      61
#
# <ipython-input-19-31aa2cbd2fae> in main()
#      53
#      54 def main():
# ---> 55     menu_sales_data()
#      56     generate_report()
#      57
#
# <ipython-input-19-31aa2cbd2fae> in menu_sales_data()
#      11
#      12 def menu_sales_data():
# ---> 13     with open(menu_filepath, newline='') as menu_filepath:
#      14         reader = csv.reader(menu_filepath)
#      15         next(reader)
#
# UnboundLocalError: local variable 'menu_filepath' referenced before assignment
